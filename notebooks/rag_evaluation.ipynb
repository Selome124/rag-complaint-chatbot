# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.rag_pipeline import rag_answer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from src.rag_pipeline import rag_answer
#
# File c:\Users\deres\OneDrive\Desktop\week7\rag-complaint-chatbot\src\rag_pipeline.py:5
#       3 from langchain_community.embeddings import HuggingFaceEmbeddings
#       4 from langchain_community.llms import HuggingFacePipeline
# ----> 5 from langchain.prompts import PromptTemplate
#       6 from langchain.chains import LLMChain
#       7 from transformers import pipeline
#
# ModuleNotFoundError: No module named 'langchain.prompts'

# %%
evaluation_questions = [
    "What are the most common credit card complaints?",
    "Why do customers complain about loan repayment issues?",
    "What issues are reported about fraud detection?",
    "Are customers satisfied with customer service?",
    "What problems do users face with online banking?"
]

# %%
results = []

for q in evaluation_questions:
    answer, docs = rag_answer(q)

    results.append({
        "Question": q,
        "Generated Answer": answer,
        "Retrieved Source 1": docs[0].page_content[:300],
        "Retrieved Source 2": docs[1].page_content[:300],
        "Quality Score (1-5)": "",
        "Comments": ""
    })

# %%
import pandas as pd

eval_df = pd.DataFrame(results)
eval_df
